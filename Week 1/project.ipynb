# %% [markdown]
# # DX 704 Week 1 Project
#
# This week's project will build a portfolio risk and return model, and make investing recommendations for hypothetical clients.
# You will collect historical data, estimate returns and risks, construct efficient frontier portfolios, and sanity check the certainty of the maximum return portfolio.

# %% [markdown]
# The full project description and a template notebook are available on GitHub at the following link.
#
# https://github.com/bu-cds-dx704/dx704-project-01

# %% [markdown]
# Feel free to use optimization tools or libraries (such as CVXOPT or scipy.optimize) to perform any calculations required for this mini project.

# %% [markdown]
# ### Example Code
#
# You may find it helpful to refer to these GitHub repositories of Jupyter notebooks for example code.
#
# * https://github.com/bu-cds-omds/dx601-examples
# * https://github.com/bu-cds-omds/dx602-examples
# * https://github.com/bu-cds-omds/dx603-examples
# * https://github.com/bu-cds-omds/dx704-examples
#
# Any calculations demonstrated in code examples or videos may be found in these notebooks, and you are allowed to copy this example code in your homework answers.

# %% [markdown]
# ## Part 1: Collect Data
#
# Collect historical monthly price data for the last 24 months covering 6 different stocks.
# The data should cover 24 consecutive months including the last month that ended before this week's material was released on Blackboard.
# To be clear, if a month ends between the Blackboard release and submitting your project, you do not need to add that month.
#
# The six different stocks must include AAPL, SPY and TSLA.
# At least one of the remaining 3 tickers must start with the same letter as your last name (e.g. professor Considine could use COIN).
# This is to encourage diversity in what stocks you analyze; if you discuss this project with classmates, please make sure that you pick different tickers to differentiate your work.
# Do not pick stocks with fewer than 24 consecutive months of price data.

# %%
import pandas as pd

# %%
# !uv pip install yfinance
# Out:
# Using Python 3.12.13 environment at: /Users/calebhadley/Projects/Fall_2026/AI_in_the_Field_Coursework/.venv
# Checked 1 package in 31ms

# %%
# Note: Sometimes this code will fail if Yahoo pushes out an update. Wait for new library version from yfinance and re-run
import yfinance as yf

# disable the yfinance cache to prevent the 'database is locked' error
yf.set_tz_cache_location(None)

# HADLEY -> 
# A -> ABNB
# D -> DDOG
# Also picking a random one i am interested in -> COF
tickers = ['AAPL', 'SPY', 'TSLA', 'ABNB', 'DDOG', 'COF'] # Apple, S&P 500, Tesla, Airbnb, Datadog, Capital One

# September 2024 to August 2026 inclusive (24 mnths)
start_date = '2024-09-01'
end_date = '2026-09-01'

print(f"Downloading historical daily data for: {tickers}")

raw_daily_data = yf.download(tickers, start=start_date, end=end_date)
raw_daily_data
# Out:
# ...
# [*********************100%***********************]  6 of 6 completed
# Price            Close                                                  \
# Ticker            AAPL        ABNB         COF        DDOG         SPY
# Date
# 2024-09-03  220.921951  114.980003  141.644913  111.480003  539.312622
# 2024-09-04  219.017883  115.209999  139.864639  108.650002  538.208862
# 2024-09-05  220.535187  116.160004  138.230255  110.089996  536.899780
# 2024-09-06  218.988129  114.279999  135.224197  107.199997  527.863647
# 2024-09-09  219.077393  116.360001  138.726440  107.699997  533.773682
# ...                ...         ...         ...         ...         ...
# 2026-08-25  309.899994  190.500000  216.240005  222.990005  765.909973
# 2026-08-26  313.450012  188.070007  217.210007  227.669998  766.080017
# 2026-08-27  314.579987  184.399994  216.669998  242.929993  771.099976
# 2026-08-28  319.700012  189.429993  215.669998  236.979996  769.349976
# ...

# %%
daily_close = raw_daily_data['Close']
daily_close
# Out:
# Ticker            AAPL        ABNB         COF        DDOG         SPY  \
# Date
# 2024-09-03  220.921951  114.980003  141.644913  111.480003  539.312622
# 2024-09-04  219.017883  115.209999  139.864639  108.650002  538.208862
# 2024-09-05  220.535187  116.160004  138.230255  110.089996  536.899780
# 2024-09-06  218.988129  114.279999  135.224197  107.199997  527.863647
# 2024-09-09  219.077393  116.360001  138.726440  107.699997  533.773682
# ...                ...         ...         ...         ...         ...
# 2026-08-25  309.899994  190.500000  216.240005  222.990005  765.909973
# 2026-08-26  313.450012  188.070007  217.210007  227.669998  766.080017
# 2026-08-27  314.579987  184.399994  216.669998  242.929993  771.099976
# 2026-08-28  319.700012  189.429993  215.669998  236.979996  769.349976
# 2026-08-31  316.850006  183.220001  214.509995  237.039993  767.049988
#
# Ticker            TSLA
# Date
# 2024-09-03  210.600006
# 2024-09-04  219.410004
# 2024-09-05  230.169998
# ...

# %%
# Resample the daily data to the last trading day of each month
# 'ME' stands for Month End, and .last() captures the final trading session price
monthly_prices = daily_close.resample('ME').last()
monthly_prices
# Out:
# Ticker            AAPL        ABNB         COF        DDOG         SPY  \
# Date
# 2024-09-30  231.067093  126.809998  145.662720  115.059998  562.210449
# 2024-10-31  224.035904  134.789993  158.367966  125.440002  557.193542
# 2024-11-30  235.620117  136.110001  187.400284  152.750000  590.420898
# 2024-12-31  248.615784  131.410004  174.038956  142.889999  576.215332
# 2025-01-31  234.299667  131.169998  198.819382  142.710007  591.690369
# 2025-02-28  240.361588  138.869995  196.317932  116.550003  584.178955
# 2025-03-31  220.772079  119.459999  175.516357   99.209999  551.628906
# 2025-04-30  211.200943  121.919998  176.456070  102.160004  546.846252
# 2025-05-31  199.883942  129.000000  185.749542  117.879997  581.212769
# 2025-06-30  204.183167  132.339996  208.935089  134.330002  611.079041
# 2025-07-31  206.571609  132.410004  211.134827  139.979996  625.153198
# 2025-08-31  231.285629  130.529999  223.742355  136.679993  637.981018
# ...

# %% [markdown]
# Save the data as a TSV file named "historical_prices.tsv" and include a header row with the column names "date" and the 6 stock ticker symbols.
# The date should be the last trading day of the month, so it may not be the last day of the month.
# For example, the last trading day of November 2024 was 2024-11-29.
# The remaining columns should contain the adjusted closing prices of the corresponding stock tickers on that day.

# %%
monthly_prices.reset_index(inplace=True)
monthly_prices.columns.name = None
monthly_prices.rename(columns={'Date': 'date'}, inplace=True)
monthly_prices
# Out:
#          date        AAPL        ABNB         COF        DDOG         SPY  \
# 0  2024-09-30  231.067093  126.809998  145.662720  115.059998  562.210449
# 1  2024-10-31  224.035904  134.789993  158.367966  125.440002  557.193542
# 2  2024-11-30  235.620117  136.110001  187.400284  152.750000  590.420898
# 3  2024-12-31  248.615784  131.410004  174.038956  142.889999  576.215332
# 4  2025-01-31  234.299667  131.169998  198.819382  142.710007  591.690369
# 5  2025-02-28  240.361588  138.869995  196.317932  116.550003  584.178955
# 6  2025-03-31  220.772079  119.459999  175.516357   99.209999  551.628906
# 7  2025-04-30  211.200943  121.919998  176.456070  102.160004  546.846252
# 8  2025-05-31  199.883942  129.000000  185.749542  117.879997  581.212769
# 9  2025-06-30  204.183167  132.339996  208.935089  134.330002  611.079041
# 10 2025-07-31  206.571609  132.410004  211.134827  139.979996  625.153198
# 11 2025-08-31  231.285629  130.529999  223.742355  136.679993  637.981018
# ...

# %%
monthly_prices.to_csv("historical_prices.tsv", sep='\t', index=False)

# %%
# Sometimes the yfinance fails and we have to manually load the data from step 1
monthly_prices = pd.read_csv('historical_prices.tsv', sep='\t')

# %% [markdown]
# Submit "historical_prices.tsv" in Gradescope.

# %% [markdown]
# ## Part 2: Calculate Historical Asset Returns
#
# Calculate the historical asset returns based on the price data that you previously collected.

# %%
from matplotlib import pyplot as plt


monthly_prices.plot(x='date')
plt.title("Historical Prices Sept 2024 - Aug 2026 (Monthly)")
plt.xlabel("Date")
plt.ylabel("Price")
None

# %%
returns_cols = monthly_prices.columns[1:]  # Exclude the 'date' column

# Calculate historical asset returns based on the monthly prices
# Return = (ending price - starting price) / starting price
monthly_returns = monthly_prices[returns_cols].pct_change()

monthly_returns.dropna(inplace=True)  # Sept will not have percent change since it's first month
monthly_returns['date'] = monthly_prices['date']
monthly_returns
# Out:
#         AAPL      ABNB       COF      DDOG       SPY      TSLA        date
# 1  -0.030429  0.062929  0.087224  0.090214 -0.008924 -0.045025  2024-10-31
# 2   0.051707  0.009793  0.183322  0.217714  0.059633  0.381469  2024-11-30
# 3   0.055155 -0.034531 -0.071298 -0.064550 -0.024060  0.170008  2024-12-31
# 4  -0.057583 -0.001826  0.142384 -0.001260  0.026856  0.001882  2025-01-31
# 5   0.025873  0.058702 -0.012582 -0.183309 -0.012695 -0.275877  2025-02-28
# 6  -0.081500 -0.139771 -0.105959 -0.148777 -0.055719 -0.115435  2025-03-31
# 7  -0.043353  0.020593  0.005354  0.029735 -0.008670  0.088748  2025-04-30
# 8  -0.053584  0.058071  0.052667  0.153876  0.062845  0.227885  2025-05-31
# 9   0.021509  0.025891  0.124822  0.139549  0.051386 -0.083126  2025-06-30
# 10  0.011698  0.000529  0.010528  0.042061  0.023032 -0.029560  2025-07-31
# 11  0.119639 -0.014198  0.059713 -0.023575  0.020519  0.083044  2025-08-31
# ...

# %%
import matplotlib.pyplot as plt
monthly_returns.plot(x='date')
plt.title("Historical Returns Sept 2024 - Aug 2026 (Monthly)")
plt.xlabel("Date")
plt.ylabel("Return")
None

# %% [markdown]
# Save the data as a TSV file named "historical_returns.tsv" and include a header row with the column names "date" and the 6 stock ticker symbols.
# Each row should have the date at the end of the month and the corresponding *relative* price changes.
# For example, if the previous price was \$100 and the new price is \$110, the return value should be 0.10.
# There should only be 23 rows of data in this file, since they are computed as the differences of 24 prices.

# %%
# YOUR CHANGES HERE
monthly_returns.to_csv("historical_returns.tsv", sep='\t', index=False)

# %% [markdown]
# Submit "historical_returns.tsv" in Gradescope.

# %% [markdown]
# ## Part 3: Estimate Returns
#
# Estimate the expected returns for each asset using the previously calculated return data.
# Just compute the average (mean) return for each asset over your data set; do not use other estimators that have been mentioned.
# This will serve as your estimate of expected return for each asset.

# %%
# compute mean return for each asset over the data set
mean_returns = monthly_returns.drop(columns='date').mean()
mean_returns
# Out:
# AAPL    0.015696
# ABNB    0.019051
# COF     0.019994
# DDOG    0.047739
# SPY     0.014246
# TSLA    0.027043
# dtype: float64

# %% [markdown]
# Save the estimated returns in a TSV file named "estimated_returns.tsv" and include a header row with the column names "asset" and "estimated_return".

# %%
# YOUR CHANGES HERE
mean_returns_df = pd.DataFrame(mean_returns, columns=['estimated_return'])
mean_returns_df.reset_index(inplace=True)
mean_returns_df.rename(columns={'index': 'asset'}, inplace=True)
mean_returns_df
# Out:
#   asset  estimated_return
# 0  AAPL          0.015696
# 1  ABNB          0.019051
# 2   COF          0.019994
# 3  DDOG          0.047739
# 4   SPY          0.014246
# 5  TSLA          0.027043

# %%
mean_returns_df.to_csv("estimated_returns.tsv", sep='\t', index=False)

# %% [markdown]
# Submit "estimated_returns.tsv" in Gradescope.

# %% [markdown]
# ## Part 4: Estimate Risk
#
# Estimate the covariance matrix for the asset returns to understand how the assets move together.

# %%
risk_df = monthly_returns.drop(columns=['date']).cov()
risk_df
# Out:
#           AAPL      ABNB       COF      DDOG       SPY      TSLA
# AAPL  0.004014 -0.000139  0.000048  0.006134  0.001053  0.002829
# ABNB -0.000139  0.006297  0.003069 -0.002869  0.000942  0.000212
# COF   0.000048  0.003069  0.006443  0.003170  0.001468  0.002553
# DDOG  0.006134 -0.002869  0.003170  0.044006  0.003775  0.011084
# SPY   0.001053  0.000942  0.001468  0.003775  0.001380  0.002818
# TSLA  0.002829  0.000212  0.002553  0.011084  0.002818  0.026124

# %% [markdown]
# Save the estimated covariances to a TSV file named "estimated_covariance.tsv".
# The header row should have a blank column name followed by the names of the assets.
# Each data row should start with the name of an asset for that row, and be followed by the individual covariances corresponding to that row and column's assets.
# (This is the format of pandas's `to_csv` method with `sep="\t"` when used on a covariance matrix as computed in the examples.)

# %%
risk_df
# Out:
#           AAPL      ABNB       COF      DDOG       SPY      TSLA
# AAPL  0.004014 -0.000139  0.000048  0.006134  0.001053  0.002829
# ABNB -0.000139  0.006297  0.003069 -0.002869  0.000942  0.000212
# COF   0.000048  0.003069  0.006443  0.003170  0.001468  0.002553
# DDOG  0.006134 -0.002869  0.003170  0.044006  0.003775  0.011084
# SPY   0.001053  0.000942  0.001468  0.003775  0.001380  0.002818
# TSLA  0.002829  0.000212  0.002553  0.011084  0.002818  0.026124

# %%
risk_df.to_csv("estimated_covariance.tsv", sep='\t')

# %% [markdown]
# Submit "estimated_covariance.tsv" in Gradescope.

# %% [markdown]
# ## Part 5: Construct the Maximum Return Portfolio
#
# Compute the maximum return portfolio based on your previously estimated risks and returns.

# %%
# !uv pip install cvxpy
# Out:
# Using Python 3.12.4 environment at: c:\Users\caleb\Projects\BU Fall 2026\AI_in_the_Field_Coursework\field
# Resolved 16 packages in 585ms
# ...
#  Downloaded highspy
#  Downloaded cvxpy
#  Downloaded scs
#  Downloaded scipy
# Prepared 12 packages in 1.81s
# Installed 12 packages in 401ms
#  + clarabel==0.11.1
#  + cloudpickle==3.1.2
#  + cvxpy==1.9.2
#  + highspy==1.15.1
#  + jinja2==3.1.6
#  + joblib==1.6.0
#  + markupsafe==3.0.3
#  + osqp==1.1.3
#  + qdldl==0.1.9.post1
#  + scipy==1.18.1
#  + scs==3.3.1
#  + sparsediffpy==0.3.0

# %%
import cvxpy as cp

# %%
n = len(mean_returns)
n
# Out:
# 6

# %%
x = cp.Variable(n)

# %%
objective = cp.Maximize(mean_returns.to_numpy().reshape(1, -1) @ x)

# %%
prob = cp.Problem(objective, [0 <= x, cp.sum(x) == 1])

# %%
estimated_returns_P = prob.solve()
estimated_returns_P
# Out:
# 0.047739174426754204

# %%
# It just took DataDog stock only since it was highest return
x.value.round(4)
# Out:
# array([0., 0., 0., 1., 0., 0.])

# %% [markdown]
# Save the maximum return portfolio in a TSV file named "maximum_return.tsv".
# The header row should have two columns, "asset" and "allocation".
# The allocation values should sum up to one.

# %%
# YOUR CHANGES HERE

maximum_return_df = pd.DataFrame({
    'asset': mean_returns.index,
    'allocation': x.value.round(4)
})
maximum_return_df
# Out:
#   asset  allocation
# 0  AAPL         0.0
# 1  ABNB         0.0
# 2   COF         0.0
# 3  DDOG         1.0
# 4   SPY         0.0
# 5  TSLA         0.0

# %%
estimated_return_maximum_return = x.value @ mean_returns

# %%
maximum_return_df.to_csv("maximum_return.tsv", sep='\t', index=False)

# %% [markdown]
# Submit "maximum_return.tsv" in Gradescope.

# %% [markdown]
# ## Part 6: Construct the Minimum Risk Portfolio
#
# Compute the minimum risk portfolio based on your previously estimated risks.

# %%
x_minimum_risk = cp.Variable(n)

# %%
objective = cp.Minimize(x_minimum_risk.T @ risk_df.to_numpy() @ x_minimum_risk)

# %%
prob_minimum_risk = cp.Problem(objective, [0 <= x_minimum_risk, cp.sum(x_minimum_risk) == 1])

# %%
covariance_minimum_risk = prob_minimum_risk.solve()
covariance_minimum_risk
# Out:
# np.float64(0.001300436071567661)

# %%
# YOUR CHANGES HERE

x_minimum_risk.value.round(4)
# Out:
# array([ 0.1203,  0.0912, -0.    , -0.    ,  0.7885, -0.    ])

# %% [markdown]
# Save the minimum risk portfolio in a TSV file named "minimum_risk.tsv".
# The header row should have two columns, "asset" and "allocation".
# The allocation values should sum up to one.

# %% [markdown]
# Submit "minimum_risk.tsv" in Gradescope.

# %%
minimum_risk_df = pd.DataFrame({
    'asset': mean_returns.index,
    'allocation': x_minimum_risk.value.round(4)
})
minimum_risk_df
# Out:
#   asset  allocation
# 0  AAPL      0.1203
# 1  ABNB      0.0912
# 2   COF     -0.0000
# 3  DDOG     -0.0000
# 4   SPY      0.7885
# 5  TSLA     -0.0000

# %%
estimated_return_minimum_risk = x_minimum_risk.value @ mean_returns

# %%
minimum_risk_df.to_csv("minimum_risk.tsv", sep='\t', index=False)

# %% [markdown]
# ## Part 7: Build Efficient Frontier Portfolios
#
# Compute 101 portfolios along the mean-variance efficient frontier with evenly spaced estimated returns.
# The first portfolio should be the minimum risk portfolio from part 4, and the last portfolio should be the maximum return portfolio from part 3.
# The estimated return of each portfolio should be higher than the previous by one percent of the difference between the first and last portfolios.
# That is, the estimated return of the portfolios should be similar to `np.linspace(min_risk_return, max_return, 101)`.

# %%
# so this sounds like computing a "target return" across a range
# here is proof of concept getting a target return

target_return = 0.04
x_target_return = cp.Variable(n)
objective_target_return = cp.Minimize(x_target_return.T @ risk_df.to_numpy() @ x_target_return)
prob_target_return = cp.Problem(objective_target_return, [
        0 <= x_target_return, 
        cp.sum(x_target_return) == 1,
        mean_returns.to_numpy().reshape(1, -1) @ x_target_return == target_return
    ]
)
covariance_target_return = prob_target_return.solve()
covariance_target_return
# Out:
# np.float64(0.022789725081154434)

# %%
estimated_return_target_return = x_target_return.value @ mean_returns
estimated_return_target_return
# Out:
# np.float64(0.04)

# %%
x_target_return.value.round(4)
# Out:
# array([-0.    ,  0.2612, -0.    ,  0.7269, -0.    ,  0.0119])

# %%
import numpy as np


estimated_variances = monthly_returns.drop(columns='date').var()
plt.plot(np.sqrt(estimated_variances), mean_returns, label='assets', linestyle='none', marker='o')


plt.plot(np.sqrt(covariance_minimum_risk), estimated_return_minimum_risk, label='minimum risk', marker='x', linestyle='none')
plt.plot(np.sqrt(covariance_target_return), estimated_return_target_return, label=f'target return={target_return:.2f}', marker='x', linestyle='none')
plt.legend()
plt.xlim(0)
plt.ylim(0)
plt.xlabel("expected return")
plt.ylabel("standard deviation")
plt.title("Comparison of Minimum Risk and Target Return Portfolios")
None

# %%
estimated_return_minimum_risk
# Out:
# np.float64(0.014858735323976465)

# %%
estimated_return_maximum_return
# Out:
# np.float64(0.047739174426754204)

# %%
target_returns = np.linspace(estimated_return_minimum_risk, estimated_return_maximum_return, 101)
target_returns[:5], target_returns[-5:]
# Out:
# (array([0.01485874, 0.01518754, 0.01551634, 0.01584515, 0.01617395]),
#  array([0.04642396, 0.04675276, 0.04708157, 0.04741037, 0.04773917]))

# %%
efficient_frontier_dfs = []
for i, target_return in enumerate(target_returns):
    x_target_return = cp.Variable(n)
    objective_target_return = cp.Minimize(x_target_return.T @ risk_df.to_numpy() @ x_target_return)
    prob_target_return = cp.Problem(objective_target_return, [
            0 <= x_target_return, 
            cp.sum(x_target_return) == 1,
            mean_returns.to_numpy().reshape(1, -1) @ x_target_return == target_return
        ]
    )
    covariance_target_return = prob_target_return.solve()
    
    risk = np.sqrt(covariance_target_return)

    efficient_frontier_df = pd.DataFrame({
        'asset': mean_returns.index,
        'allocation': x_target_return.value.round(4)
    })
    efficient_frontier_df = efficient_frontier_df.set_index('asset').T.reset_index(drop=True)
    efficient_frontier_df['return'] = x_target_return.value @ mean_returns
    efficient_frontier_df['risk'] = risk

    efficient_frontier_dfs.append(efficient_frontier_df)
result = pd.concat(efficient_frontier_dfs)
result.reset_index(inplace=True, drop=True)
result
# Out:
# asset    AAPL    ABNB     COF    DDOG     SPY  TSLA    return      risk
# 0      0.1203  0.0912  0.0000  0.0000  0.7885   0.0  0.014859  0.036062
# 1      0.1550  0.1279  0.0177  0.0000  0.6993   0.0  0.015188  0.036307
# 2      0.1676  0.1419  0.0348  0.0043  0.6513  -0.0  0.015516  0.036825
# 3      0.1681  0.1539  0.0382  0.0118  0.6279  -0.0  0.015845  0.037409
# 4      0.1687  0.1659  0.0417  0.0193  0.6044  -0.0  0.016174  0.038038
# ..        ...     ...     ...     ...     ...   ...       ...       ...
# 96    -0.0000  0.0458 -0.0000  0.9542 -0.0000  -0.0  0.046424  0.199563
# 97    -0.0000  0.0344 -0.0000  0.9656 -0.0000  -0.0  0.046753  0.202110
# 98     0.0000  0.0229  0.0000  0.9771 -0.0000   0.0  0.047082  0.204661
# 99     0.0000  0.0115 -0.0000  0.9885 -0.0000  -0.0  0.047410  0.207216
# 100    0.0000  0.0000  0.0000  1.0000 -0.0000   0.0  0.047739  0.209775
#
# [101 rows x 8 columns]

# %%
estimated_variances
# Out:
# AAPL    0.004014
# ABNB    0.006297
# COF     0.006443
# DDOG    0.044006
# SPY     0.001380
# TSLA    0.026124
# dtype: float64

# %%
mean_returns
# Out:
# AAPL    0.015696
# ABNB    0.019051
# COF     0.019994
# DDOG    0.047739
# SPY     0.014246
# TSLA    0.027043
# dtype: float64

# %%
risk_df
# Out:
#           AAPL      ABNB       COF      DDOG       SPY      TSLA
# AAPL  0.004014 -0.000139  0.000048  0.006134  0.001053  0.002829
# ABNB -0.000139  0.006297  0.003069 -0.002869  0.000942  0.000212
# COF   0.000048  0.003069  0.006443  0.003170  0.001468  0.002553
# DDOG  0.006134 -0.002869  0.003170  0.044006  0.003775  0.011084
# SPY   0.001053  0.000942  0.001468  0.003775  0.001380  0.002818
# TSLA  0.002829  0.000212  0.002553  0.011084  0.002818  0.026124

# %%
plt.plot(np.sqrt(estimated_variances), mean_returns, label='assets', linestyle='none', marker='o')
plt.plot(result['risk'], result['return'], label='efficient frontier', linestyle='--')
plt.xlabel('standard deviation')
plt.ylabel('expected return')
plt.title('Mean-Variance Efficient Frontier and Individual Assets')
plt.legend()
plt.xlim(0)
plt.ylim(0)
None

# %%
# 1. Identify your true asset columns by excluding tracking columns
# (Adjust this list if you have other columns like 'risk' or 'volatility')
tracking_cols = ['return', 'date']
asset_cols = [col for col in result.columns if col not in tracking_cols]

# 2. Initialize bottom using the length of the DataFrame
bottom = np.zeros(len(result))

# 3. Dynamically calculate the bar width from the 'return' column
bar_width = result['return'].iloc[1] - result['return'].iloc[0]

# 4. Loop only through your asset columns
for col in asset_cols:
    plt.bar(
        x=result['return'],
        height=result[col],       # Selects ONLY the specific asset column by name
        bottom=bottom,
        label=col,
        width=bar_width
    )
    bottom += result[col]        # Stack the weights sequentially

plt.legend()
plt.xlabel("Portfolio Expected Return")
plt.xlim(estimated_return_minimum_risk, estimated_return_maximum_return)
plt.ylabel("Portfolio Allocation")
plt.title("Portfolio Composition Map of the Mean-Variance Efficient Frontier")
# Out:
# Text(0.5, 1.0, 'Portfolio Composition Map of the Mean-Variance Efficient Frontier')

# %% [markdown]
# Save the portfolios in a TSV file named "efficient_frontier.tsv".
# The header row should have columns "index", "return", "risk", and all the asset tickers.
# Each data row should have the portfolio index (0-100), the estimated return of the portfolio, the estimated standard deviation (not variance) of the portfolio, and all the asset allocations (which should sum to one).

# %%
result.reset_index()
# Out:
# asset  index    AAPL    ABNB     COF    DDOG     SPY  TSLA    return      risk
# 0          0  0.1203  0.0912  0.0000  0.0000  0.7885   0.0  0.014859  0.036062
# 1          1  0.1550  0.1279  0.0177  0.0000  0.6993   0.0  0.015188  0.036307
# 2          2  0.1676  0.1419  0.0348  0.0043  0.6513  -0.0  0.015516  0.036825
# 3          3  0.1681  0.1539  0.0382  0.0118  0.6279  -0.0  0.015845  0.037409
# 4          4  0.1687  0.1659  0.0417  0.0193  0.6044  -0.0  0.016174  0.038038
# ..       ...     ...     ...     ...     ...     ...   ...       ...       ...
# 96        96 -0.0000  0.0458 -0.0000  0.9542 -0.0000  -0.0  0.046424  0.199563
# 97        97 -0.0000  0.0344 -0.0000  0.9656 -0.0000  -0.0  0.046753  0.202110
# 98        98  0.0000  0.0229  0.0000  0.9771 -0.0000   0.0  0.047082  0.204661
# 99        99  0.0000  0.0115 -0.0000  0.9885 -0.0000  -0.0  0.047410  0.207216
# 100      100  0.0000  0.0000  0.0000  1.0000 -0.0000   0.0  0.047739  0.209775
#
# [101 rows x 9 columns]

# %%
# YOUR CHANGES HERE

result.reset_index().to_csv("efficient_frontier.tsv", sep='\t', index=False)

# %% [markdown]
# Submit "efficient_frontier.tsv" in Gradescope.

# %% [markdown]
# ## Part 8: Check Maximum Return Portfolio Stability
#
# Check the stability of the maximum return portfolio by resampling the estimated risk/return model.
#
# Repeat 1000 times -
# 1. Use `np.random.multivariate_normal` to generate 23 return samples using your previously estimated risks and returns.
# 2. Estimate the return of each asset using that resampled return history.
# 3. Check which asset had the highest return in those resampled estimates.
#
# This procedure is a reduced and simplified version of the Michaud resampled efficient frontier procedure that takes uncertainty in the risk model into account.

# %%
mean_returns
# Out:
# AAPL    0.015696
# ABNB    0.019051
# COF     0.019994
# DDOG    0.047739
# SPY     0.014246
# TSLA    0.027043
# dtype: float64

# %%
risk_df # covariance matrix
# Out:
#           AAPL      ABNB       COF      DDOG       SPY      TSLA
# AAPL  0.004014 -0.000139  0.000048  0.006134  0.001053  0.002829
# ABNB -0.000139  0.006297  0.003069 -0.002869  0.000942  0.000212
# COF   0.000048  0.003069  0.006443  0.003170  0.001468  0.002553
# DDOG  0.006134 -0.002869  0.003170  0.044006  0.003775  0.011084
# SPY   0.001053  0.000942  0.001468  0.003775  0.001380  0.002818
# TSLA  0.002829  0.000212  0.002553  0.011084  0.002818  0.026124

# %%
n_repeats = 1_000
asset_names = mean_returns.index
winner_counts = np.zeros(len(asset_names), dtype=int)

for repeat in range(n_repeats):
    # Check stability of max return portfolio by resampling the estimated risk/return model

    # Generate 23 return samples using previously estimated risks and rewards
    samples = np.random.multivariate_normal(mean=mean_returns, cov=risk_df, size=23)

    # Estimate return of each asset using that resampled return history
    resampled_mean_returns = samples.mean(axis=0)

    # Check which asset had highest return in those resampled estimates
    winning_asset_index = np.argmax(resampled_mean_returns)
    winner_counts[winning_asset_index] += 1
winner_counts
# Out:
# array([ 26, 130,  59, 578,   2, 205])

# %% [markdown]
# Save a file "max_return_probabilities.tsv" with the distribution of highest return assets.
# The header row should have columns "asset" and "probability".
# There should be a data row for each asset and its sample probability of having the highest return based on those 1000 resampled estimates.

# %%
max_return_probabilities_df = pd.DataFrame({
    'asset': asset_names,
    'probability': winner_counts/n_repeats
})
max_return_probabilities_df
# Out:
#   asset  probability
# 0  AAPL        0.026
# 1  ABNB        0.130
# 2   COF        0.059
# 3  DDOG        0.578
# 4   SPY        0.002
# 5  TSLA        0.205

# %%
max_return_probabilities_df.to_csv('max_return_probabilities.tsv', sep='\t', index=False)

# %% [markdown]
# Submit "max_return_probabilities.tsv" in Gradescope.

# %% [markdown]
# ## Part 9: Acknowledgments
#
# Make a file "acknowledgments.txt" documenting any outside sources or help on this project.
# If you discussed this assignment with anyone, please acknowledge them here.
# If you used any libraries not mentioned in this module's content, please list them with a brief explanation what you used them for.
# If you used any generative AI tools, please add links to your transcripts below, and any other information that you feel is necessary to comply with the generative AI policy.
# If no acknowledgments are appropriate, just write none in the file.

# %% [markdown]
# Submit "acknowledgments.txt" in Gradescope.

# %% [markdown]
# ## Part 10: Code
#
# Please submit a Jupyter notebook that can reproduce all your calculations and recreate the previously submitted files.
# You do not need to provide code for data collection if you did that by manually.

# %% [markdown]
# Submit "project.ipynb" in Gradescope.
